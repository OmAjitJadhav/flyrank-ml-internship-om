# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose **Lane 2: Refresh / Content Opportunity Scoring** because it focuses on identifying web pages that should be prioritized for content updates based on search performance, engagement metrics, and content freshness. This lane helps make data-driven decisions by ranking pages with the highest potential for improvement, allowing teams to focus their efforts where they can have the greatest impact.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Research Question:** Which web pages should be prioritized for content refresh based on search performance, engagement metrics, and content freshness?
#
# **Decision:** Decide which pages should be refreshed first.
#
# **Who acts on it:** SEO specialists, content managers, or website owners.
#
# **Action:** Prioritize high-impact pages for content updates instead of reviewing every page manually.
#
# **Cost of a wrong call:** If the wrong pages are selected, valuable pages may continue losing traffic while time and resources are spent updating pages with little or no impact.

# %% [markdown]
# ## 3. Quick look at the data (2 3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains **30,000 content pages**, **44 features**, and data from **32 unique clients**. These numbers show that the dataset is large enough to analyze content refresh opportunities and identify pages that should be prioritized for improvement.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print(df.shape)
df.head()
# Out:
# (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision support by identifying patterns and ranking pages for content refresh based on observed data. It does not prove that refreshing a page will improve rankings or traffic, nor does it predict Google's algorithm. The recommendations should be reviewed by humans before action is taken.

# %%
print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Unique clients:", df["client_id"].nunique())
print("Unique content pages:", df["content_id"].nunique())
# Out:
# Rows: 30000
# Columns: 44
# Unique clients: 32
# Unique content pages: 30000

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
