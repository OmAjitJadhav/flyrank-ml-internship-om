# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/OmAjitJadhav/flyrank-ml-internship-om/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print(df.shape)
df.head()
# Out:
# (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ## Unit of Analysis + Time Window
#
# - One row represents one content page (web page).
# - I will use the content refresh dataset together with search performance features for each page.
# - I will use a development window such as `month=2026-03` to build and verify features.
# - The model will rank pages based on their content refresh opportunity score.
# - The final month (June 2026) will be treated as the test month and will not be used to create features.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ## Fields: Feature / Label / Context / Excluded
#
# ### Features
# - search_volume
# - competition
# - competition_level
# - cpc
# - main_intent
# - word_count
# - engagement_rate
# - scroll_rate
# - ai_traffic_pct
#
# ### Label
# - Content refresh opportunity score (ranking score for each page).
#
# ### Context
# - content_id
# - client_id
# - content_type
#
# ### Excluded
# - Future information from the final test month (June 2026), because it would cause data leakage.
# - trend_direction because it is derived from the target and would leak label information.
# - trend_pct because it is used to compute the target and would leak label information.
#
# ### Output
#
# A ranked list of content pages ordered by content refresh opportunity score so the SEO team can prioritize which pages to refresh.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 30000
# Columns: 44

# %%
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# provider_used        21438
# word_count            7699
# char_count            7699
# word_count_tier       7699
# char_count_tier       7699
# model_used            5733
# trend_pct             3388
# competition_level     2610
# search_volume         2468
# cpc                   2468
# dtype: int64

# %%
print(df["trend_direction"].value_counts())
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## Verification Summary
#
# - Query 1 verifies the size of the dataset.
# - Query 2 checks for missing values that may affect model training.
# - Query 3 verifies the distribution of trend directions to better understand the data before building the ranking model.
# - Missing values are not completely random and may depend on content type, so they should be handled carefully instead of blindly replacing them with zeros.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
print(df.isnull().sum().sort_values(ascending=False).head())
# Out:
# provider_used      21438
# word_count          7699
# char_count          7699
# word_count_tier     7699
# char_count_tier     7699
# dtype: int64

# %% [markdown]
# ## Data Limits
#
# - The dataset cannot prove that refreshing a page will increase traffic or rankings.
# - Some columns contain missing values, which may affect analysis.
# - The dataset contains historical observations and may not reflect future search behavior.
# - Future data must not be used for feature creation because it causes data leakage.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
